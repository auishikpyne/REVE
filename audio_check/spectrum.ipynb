# %%
# Beat tracking example
import librosa
import os

#os.environ['LIBROSA_DATA_DIR'] = '/home/auishik/Downloads/test.wav'
# 1. Get the file path to an included audio example
#filename = librosa.example('/home/auishik/Documents/10small.wav')
audio_data = '/home/auishik/Downloads/test.wav'
# # 2. Load the audio as a waveform `y`
# #    Store the sampling rate as `sr`
y, sr = librosa.load(audio_data)
print('sample:', len(y), 'sample rate:', sr)

# # 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)

print('Estimated tempo: {:.2f} beats per minute'.format(tempo))

# # 4. Convert the frame indices of beat events into timestamps
# beat_times = librosa.frames_to_time(beat_frames, sr=sr)
# Out:
# sample: 1958976 sample rate: 22050
# Estimated tempo: 99.38 beats per minute

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveshow(y, sr=sr)

# %%
# Beat tracking example
import librosa
import os

#os.environ['LIBROSA_DATA_DIR'] = '/home/auishik/Downloads/test.wav'
# 1. Get the file path to an included audio example
#filename = librosa.example('/home/auishik/Documents/10small.wav')
audio_data = '/home/auishik/Downloads/test.mp3'
# # 2. Load the audio as a waveform `y`
# #    Store the sampling rate as `sr`
y, sr = librosa.load(audio_data)
print('sample:', len(y), 'sample rate:', sr)

# # 3. Run the default beat tracker
# tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)

# print('Estimated tempo: {:.2f} beats per minute'.format(tempo))

# # 4. Convert the frame indices of beat events into timestamps
# beat_times = librosa.frames_to_time(beat_frames, sr=sr)
# Out:
# /home/auishik/.local/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# sample: 1958976 sample rate: 22050

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveshow(y, sr=sr)

# %%
from mutagen.mp3 import MP3
f = MP3('/home/auishik/Downloads/test.mp3')
f.info.bitrate/1000
# Out:
# 256.0

# %%
import wave
wav = wave.open('/home/auishik/Downloads/test.wav', 'rb')

# %%
n_samples = wav.getnframes()
n_samples
# Out:
# 3917952

# %%
sample_freq = wav.getframerate()
sample_freq
# Out:
# 44100

# %%
n_channels = wav.getnchannels()
n_channels
# Out:
# 2

# %%
t_audio = n_samples/sample_freq
t_audio
# Out:
# 88.84244897959184

# %%
signal_wave = wav.readframes(n_samples)
signal_wave
# Out:
# b''

# %%
import numpy as np
times = np.linspace(0, n_samples/sample_freq, num=n_samples)

# %%
times
# Out:
# array([0.00000000e+00, 2.26757427e-05, 4.53514855e-05, ...,
#        8.88424036e+01, 8.88424263e+01, 8.88424490e+01])
