# %%
import os
from scipy.io import wavfile
samplerate, data = wavfile.read('/home/auishik/Documents/10small.wav')
# Out:
# /tmp/ipykernel_8410/2877320562.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplerate, data = wavfile.read('/home/auishik/Documents/10small.wav')

# %%
file_size = os.path.getsize('/home/auishik/Documents/10small.wav')
file_size
# Out:
# 13988456

# %%
if file_size > 12 * 1024 * 1024:
    print('The data value transmitted exceeds the capacity limit.')
else:
    pass
# Out:
# The data value transmitted exceeds the capacity limit.

# %%
file_name, file_extension = os.path.splitext("/home/auishik/Documents/10small.wav")

# %%
import wave
try:
    file = wave.open('/media/auishik/New Volume/Official/audio_files/8 & 9/2608.wav', mode = 'rb')
    print('this is a valid wav file.')
except:
    print('This is not a WAV file. Please upload a .WAV file.')
# Out:
# This is not a WAV file. Please upload a .WAV file.

# %%
from wave import Wave_read
Wave_read.getparams(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8410/2940597237.py in <module>
#       1 from wave import Wave_read
# ----> 2 Wave_read.getparams(file)
#
# NameError: name 'file' is not defined

# %%
import base64
with open('/home/auishik/Downloads/test.mp3', 'rb') as f:
    data = f.read()
# data = open("/home/auishik/Downloads/test.mp3", "r").read()
encoded = base64.b64encode(data)

# %%
encoded
# Out:
# b'...'

# %%
from os.path import dirname, join as pjoin
from scipy.io import wavfile
import scipy.io

# %%
samplerate, data = wavfile.read('/home/auishik/Documents/10small.wav')
# Out:
# /tmp/ipykernel_9383/1957743605.py:1: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplerate, data = wavfile.read('/home/auishik/Documents/10small.wav')

# %%
data
# Out:
# array([[6958, 6961],
#        [5832, 5830],
#        [4699, 4700],
#        ...,
#        [ 817,  819],
#        [ 611,  608],
#        [ 687,  690]], dtype=int16)

# %%
print(f"number of channels = {data.shape[1]}")
# Out:
# number of channels = 2

# %%
length = data.shape[0] / samplerate

# %%
print(f"length = {length}s")
# Out:
# length = 72.8558125s

# %%
import matplotlib.pyplot as plt
import numpy as np
time = np.linspace(0., length, data.shape[0])
plt.plot(time, data[:, 0], label="Left channel")
plt.plot(time, data[:, 1], label="Right channel")
plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()

# %%
data[:, 0]
# Out:
# array([6958, 5832, 4699, ...,  817,  611,  687], dtype=int16)

# %%
import glob
from scipy.io.wavfile import read

wavs = []
try:
    for filename in glob.glob('/home/auishik/Downloads/test1.wav'):
        print('valid')
except:
     print('Enter valid WAV file.')

# %%
len(wavs)
# Out:
# 0

# %%
# Beat tracking example
import librosa

# 1. Get the file path to an included audio example
filename = librosa.example()


# 2. Load the audio as a waveform `y`
#    Store the sampling rate as `sr`
y, sr = librosa.load(filename)

# 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)

print('Estimated tempo: {:.2f} beats per minute'.format(tempo))

# 4. Convert the frame indices of beat events into timestamps
beat_times = librosa.frames_to_time(beat_frames, sr=sr)
